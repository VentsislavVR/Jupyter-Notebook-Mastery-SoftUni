# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.xlabel('something')
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'y')
plt.axis((0,6,0,20)) # xmin , xmax , ymin , ymax)
# plt.xlim()
# plt.ylim()
plt.show()

# %%
import numpy as np
# evenly sampled time at 200ms intervals
t = np.arange(0.,5.,0.2)
# red dashes , blue squares and green triangles
plt.plot(t,t, 'r--',t,t**2 , 'bs',t, t**3 , 'g^')
plt.show()

# %%
# plotimg labaled data 

import pandas as pd 
data = pd.DataFrame({
    'a':np.arange(50),
    'c': np.random.randint(0,50,50),
    'd': np.random.randn(50)
    })
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b' , c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a','group_b','group_c']
values = [1, 10, 100]

plt.figure(figsize=(9,3))

plt.subplot(131)
plt.bar(names,values)

plt.subplot(132)
plt.scatter(names,values)

plt.subplot(133)
plt.subplot(names,values)
plt.subtitle('Categorical Plotting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7 plt.scatter(names,values)
#       8 plt.subplot(133)
# ----> 9 plt.subplot(names,values)
#      10 plt.subtitle('Categorical Plotting')
#      11 plt.show()
#
# File D:\GIT Repos\Jupyter-Notebook-Mastery-SoftUni\venv\Lib\site-packages\matplotlib\pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
#    1433                  == fig._process_projection_requirements(**kwargs)))):
#
# File D:\GIT Repos\Jupyter-Notebook-Mastery-SoftUni\venv\Lib\site-packages\matplotlib\gridspec.py:586, in SubplotSpec._from_subplot_args(figure, args)
#     584     rows, cols, num = args
#     585 else:
# --> 586     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     588 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     589 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given
